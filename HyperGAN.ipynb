# %% [markdown]
# <a href="https://colab.research.google.com/github/sajjad-shirazy/python-notebooks/blob/master/HyperGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import zipfile

# zip_ref = zipfile.ZipFile("/content/gdrive/My Drive/ML/logo-grayscale.zip", 'r')
zip_ref = zipfile.ZipFile("/content/gdrive/My Drive/ML/abstracts-flat-shapes.zip", 'r')
zip_ref.extractall("/data/")
zip_ref.close()

# %%
# !ls /data/abstracts-flat-shapes -U | head -4
# Out:
# untitled-1_9_9.png
# untitled-1_448.png
# brand_2022.png
# untitled-1_57_8.png

# %%
# !pip3 install hypergan --upgrade

# %%
# !pip3 install numpy tensorflow-gpu hyperchamber pillow pygame

# %%
# !git clone https://github.com/hypergan/hypergan
# %cd hypergan
# !python setup.py develop
# Out:
# Cloning into 'hypergan'...
# remote: Enumerating objects: 343, done.
# remote: Counting objects: 100% (343/343), done.
# remote: Compressing objects: 100% (234/234), done.
# remote: Total 16789 (delta 233), reused 205 (delta 107), pack-reused 16446
# Receiving objects: 100% (16789/16789), 18.42 MiB | 30.09 MiB/s, done.
# Resolving deltas: 100% (12362/12362), done.
# /content/hypergan
# running develop
# running egg_info
# creating hypergan.egg-info
# writing hypergan.egg-info/PKG-INFO
# writing dependency_links to hypergan.egg-info/dependency_links.txt
# writing top-level names to hypergan.egg-info/top_level.txt
# writing manifest file 'hypergan.egg-info/SOURCES.txt'
# package init file 'hypergan/optimizers/__init__.py' not found (or not a regular file)
# package init file 'hypergan/train_hooks/__init__.py' not found (or not a regular file)
# package init file 'hypergan/optimizers/experimental/__init__.py' not found (or not a regular file)
# ...

# %%
# !pip install nashpy
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/13/6d/f9/47642eb1a337f9b22222a123aaa89378e5e3bbfea99cc5418a
# Successfully built nashpy
# ...

# %%
# !hypergan test
# Out:
# Loading configuration /content/hypergan/hypergan/configurations/default.json
# Hooray!
# Hypergan is installed correctly.  Testing tensorflow for GPU support.
# 2019-05-26 06:56:11.391638: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-05-26 06:56:11.639377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-26 06:56:11.639934: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2fc6100 executing computations on platform CUDA. Devices:
# 2019-05-26 06:56:11.639964: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-05-26 06:56:11.642125: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# ...

# %%
# %cd /content/
# !rm -r /content/samples/*
# !rm -r /content/saves/*
# !rm -r /content/mymodel.json
# Out:
# /content
# rm: cannot remove '/content/samples/*': No such file or directory
# rm: cannot remove '/content/saves/*': No such file or directory
# rm: cannot remove '/content/mymodel.json': No such file or directory

# %%
# !hypergan new mymodel
# Out:
# Loading configuration /content/hypergan/hypergan/configurations/default.json
# [hypergan] Creating new configuration file 'mymodel.json' based off of 'default.json'
# Loading configuration /content/hypergan/hypergan/configurations/default.json

# %%
# !hypergan train /data/abstracts-flat-shapes --size 128x128x1 -f png -c mymodel --noviewer --save_samples --sample_every 100 --steps 20000 --resize --save_every 1000
# Out:
# Loading configuration /content/mymodel.json
# [loader] ImageLoader found 154
# Shuffling data
# 2019-05-26 06:56:46.942299: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-05-26 06:56:47.154222: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-26 06:56:47.154835: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2684100 executing computations on platform CUDA. Devices:
# 2019-05-26 06:56:47.154874: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-05-26 06:56:47.157257: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# ...

# %%
# !ls './out/20190520.084658 -  - resized - x108.z100.uniform_signed.y64.b64/samples'
# Out:
# train_00000200.png  train_00000400.png

# %%
from google.colab import files
files.download('./out/20190520.084658 -  - resized - x108.z100.uniform_signed.y64.b64/samples/train_00000400.png')
